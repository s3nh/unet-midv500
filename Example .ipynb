# %%
from src.utils import pad, unpad
from src.dataset import MidvDataset
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-9ec5456f8a7b> in <module>
#       1 from src.utils import pad, unpad
# ----> 2 from src.dataset import MidvDataset
#       3 import cv2
#
# ~/proj/midv-500/src/dataset.py in <module>
#       3 from torchvision import transforms, datasets, models
#       4 from typing import List, Tuple, Dict, Any
# ----> 5 import albumentations
#       6 from src.utils import pad, unpad
#       7 from pytorch_toolbelt.utils.torch_utils import tensor_from_rgb_image
#
# ModuleNotFoundError: No module named 'albumentations'

# %%
import os

# %%
masks = sorted(os.listdir('data_processed/images'))
labels = sorted(os.listdir('data_processed/labels'))

# %%
import json

# %%
_res = list(zip(masks, labels))

# %%
with open('samples.json', 'w') as samples_file:
    json.dump(_res, samples_file)

# %%
with open('samples.json', 'r') as samples_file:
    _results = json.load(samples_file)
    [tuple(el) for el in _results]

# %%
# Out:
# [('CA01_01.jpg', 'CA01_01.png'),
#  ('CA01_02.jpg', 'CA01_02.png'),
#  ('CA01_03.jpg', 'CA01_03.png'),
#  ('CA01_04.jpg', 'CA01_04.png'),
#  ('CA01_05.jpg', 'CA01_05.png'),
#  ('CA01_06.jpg', 'CA01_06.png'),
#  ('CA01_07.jpg', 'CA01_07.png'),
#  ('CA01_08.jpg', 'CA01_08.png'),
#  ('CA01_09.jpg', 'CA01_09.png'),
#  ('CA01_10.jpg', 'CA01_10.png'),
#  ('CA01_11.jpg', 'CA01_11.png'),
#  ('CA01_12.jpg', 'CA01_12.png'),
#  ('CA01_13.jpg', 'CA01_13.png'),
#  ('CA01_14.jpg', 'CA01_14.png'),
#  ('CA01_15.jpg', 'CA01_15.png'),
#  ('CA01_16.jpg', 'CA01_16.png'),
#  ('CA01_17.jpg', 'CA01_17.png'),
#  ('CA01_18.jpg', 'CA01_18.png'),
#  ('CA01_19.jpg', 'CA01_19.png'),
#  ('CA01_20.jpg', 'CA01_20.png'),
#  ('CA01_21.jpg', 'CA01_21.png'),
#  ('CA01_22.jpg', 'CA01_22.png'),
#  ('CA01_23.jpg', 'CA01_23.png'),
#  ('CA01_24.jpg', 'CA01_24.png'),
#  ('CA01_25.jpg', 'CA01_25.png'),
#  ('CA01_26.jpg', 'CA01_26.png'),
#  ('CA01_27.jpg', 'CA01_27.png'),
#  ('CA01_28.jpg', 'CA01_28.png'),
# ...
