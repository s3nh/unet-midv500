# %%
#import albumentations
import cv2
import matplotlib.pyplot as plt
import numpy as np 
import os 
import pandas as pd 
from PIL import Image
import re

import torch 
import torchvision

# %%
# Model imports 

from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator

from torch.utils.data import DataLoader, Dataset
from torch.utils.data.sampler import SequentialSampler

# %%
DATA_PATH = 'data/smartwarehouseyolo/SmartWarehouseYOLO/'

# %%
len(os.listdir(os.path.join(DATA_PATH, 'data')))
# Out:
# 1998

# %%
with open(os.path.join(DATA_PATH, 'smartwarehouse_train.txt'), 'r') as trainfile:
    file = trainfile.read()

# %%
def get_boxes(txt_file):
    file = open(txt_file, 'r')
    _res = list()
    for line in file:
        line = re.sub('\n', ' ', line)
        line = [float(el) for el in line[2:-1].split(' ')]
        _res.append(line )
    return _res

# %%
_files = os.listdir(os.path.join(DATA_PATH, 'data'))
_txt_files = [os.path.join(DATA_PATH, 'data', el) for el in _files if el.endswith('.txt')]

# %% [markdown]
# #### Read random file

# %%
# Get txt file 
rd = np.random.choice(range(999))
_txt_file = open(os.path.join(DATA_PATH, 'data', f'{rd:06}.txt'), 'r')
_img_file = cv2.imread(os.path.join(DATA_PATH, 'data', f'{rd:06}.jpg'))
for line in _txt_file:
    res = line.split()
    res.insert(0, f'{rd}')
    print(res)
# Out:
# ['230', '7', '0.39474826388888884', '0.46851325757575757', '0.15060763888888887', '0.11316287878787878']

# %%
x int(float(res[2]) * _img_file.shape[1])
y_max = int(float(res[3]) * _img_file.shape[0])
x_min = int(float(res[4]) * _img_file.shape[1])
y_min = int(float(res[5]) * _img_file.shape[0])

# %%
x_min, x_max, y_min, y_max
# Out:
# (318, 833, 521, 2158)

# %%
cv2.rectangle(_img_file,  (x_min, x_max), (y_min, y_max),(255, 12, 0) , 5)
out_img = cv2.resize(_img_file, (600, 600))
cv2.imshow('output', out_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(_img_file)

# %%
for line in random_file:
    _txt_fil

# %%
get_boxes(os.path.join(DATA_PATH,'data/000003.txt') )

# %%
class SmartWareHouseDataset(Dataset):
    
    def __init__(self,  image_dir, transforms=None):
        super().__init__()
        self.txt_file = txt_file
        self.image_dir = image_dir 
        self.transforms = transforms
        self.image_ids = [ f'{el:06}' for el in range(1000)]
    
    def __getitem__(self, index: int):
        image_id = self.image_ids[index]
        image =  cv2.imread(os.path.join(self.image_dir, f'{image_id}.jpg'))
        # Convert image 
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB).astype(np.float32)
        image /= 255.0
        
        
        box = get_boxes(os.path.join(self.image_dir, f'{image_id}.txt'))
        n_boxes = len(box)
        assert n_boxes > 0, 'There are no boxes on provided image'
        
        if self.transforms:
            sample = {
                'image' : image,
            }
            sample = self.transforms(**sample)
            image = sample['image']
        return image, image_id, box

# %%
# Model pretrained on coco 
model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained = False, pretrained_backbone=False)

# %% [markdown]
# ##### Example image

# %%
img = cv2.imread(os.path.join(DATA_PATH, 'data/000002.jpg'))

# %%
boxes = get_boxes(os.path.join(DATA_PATH, 'data/000002.txt'))

# %%
boxes

# %%
img.shape[:-1]

# %%
def get_coords(boxes, img):
    n_boxes = len(boxes)
    for box in boxes:
        for coords in range(len(box)):
            (x, y) = [el * box[coords] for el in img.shape[:2]]
            
    
    (x1, y1) = [el * boxes[0][0] for el in img.shape[:2]]
    (x2, y2) = 
    y1 = 
    y2 =

# %%
plt.imshow(img)

# %%
img.shape

# %%
boxes

# %%
[float(el) for item in boxes for el in item]
